# %%
import pandas as pd

# %%
df  = pd.read_csv("U.S._Chronic_Disease_data.csv")
# Out:
# C:\Users\joyce\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (7,19,20,21,22,26,27,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2013     2013           CA            California      YRBSS  Alcohol
# 1       2013     2013           CO              Colorado      YRBSS  Alcohol
# 2       2013     2013           CT           Connecticut      YRBSS  Alcohol
# 3       2013     2013           DC  District of Columbia      YRBSS  Alcohol
# 4       2013     2013           DE              Delaware      YRBSS  Alcohol
#
#                   Question Response DataValueUnit DataValueTypeID  ...  \
# 0  Alcohol use among youth      NaN             %         CrdPrev  ...
# 1  Alcohol use among youth      NaN             %         CrdPrev  ...
# 2  Alcohol use among youth      NaN             %         CrdPrev  ...
# 3  Alcohol use among youth      NaN             %         CrdPrev  ...
# 4  Alcohol use among youth      NaN             %         CrdPrev  ...
#
#   TopicID QuestionID  ResponseID LocationID StratificationCategoryID1  \
# ...

# %%
df_cancer = df.query('Topic == "Cancer"')
print(df_cancer)
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc         DataSource  \
# 16644       2008     2012           VT        Vermont  Death certificate
# 36151       2013     2013           AZ        Arizona              BRFSS
# 36331       2013     2013           AZ        Arizona              BRFSS
# 36354       2013     2013           TX          Texas              BRFSS
# 36444       2012     2012           AZ        Arizona              BRFSS
# 36600       2013     2013           CA     California              BRFSS
# 36622       2013     2013           CA     California              BRFSS
# 37171       2012     2012           CA     California              BRFSS
# 37608       2013     2013           CO       Colorado              BRFSS
# 37899       2013     2013           CO       Colorado              BRFSS
# 39490       2013     2013           CT    Connecticut              BRFSS
# 39645       2013     2013           CT    Connecticut              BRFSS
# ...

# %%
#Filter out the garbage data
#Figure out the needed columns and create the table in my Sql that matches the column in the dataframe
#Load the dataframe into the database table-
#Try SQL ALchemy
